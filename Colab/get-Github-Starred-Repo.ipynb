# %%
# !pip install PyGithub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.5/312.5 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 40.5 MB/s eta 0:00:00
# ...

# %%
import configparser as cp
another_config = cp.ConfigParser()
another_config.read(r'/content/drive/MyDrive/github.txt')

# Provide your personal access token
access_token = another_config['global']['access_token']

# %%
from github import Github

def get_starred_repositories(access_token):
    g = Github(access_token)
    user = g.get_user()
    starred_repositories = user.get_starred()
    return starred_repositories

starred_repositories = get_starred_repositories(access_token)

for i, repo in enumerate(starred_repositories):
    repo_name = repo.full_name
    print(i,'\t', repo_name, '\t',repo.description )
# Out:
# 0 	 xingyaoww/LeTI 	 Official repo for paper "LeTI: Learning to Generate from Textual Interactions."
# 1 	 kyrolabs/awesome-langchain 	 😎 Awesome list of tools and projects with the awesome LangChain framework
# 2 	 SkalskiP/courses 	 This repository is a curated collection of links to various courses and resources about Artificial Intelligence (AI)
# 3 	 alexeygrigorev/mlbookcamp-code 	 The code from the Machine Learning Bookcamp book and a free course based on the book
# 4 	 facebookresearch/fairseq 	 Facebook AI Research Sequence-to-Sequence Toolkit written in Python.
# 5 	 aupasana/ashtadhyayi 	 Various vrittis associated with the ashtadhyayi
# 6 	 cleanlab/cleanlab 	 The standard data-centric AI package for data quality and machine learning with messy, real-world data and labels.
# 7 	 Deci-AI/super-gradients 	 Easily train or fine-tune SOTA computer vision models with one open source training library. The home of Yolo-NAS.
# ...

# %%
repo.description
# Out:
# 'Code and data associated with the book "Statistics for Data Scientists: 50 Essential Concepts"'
